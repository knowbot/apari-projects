# %% [markdown]
# # Project

# %% [markdown]
# The goal of this project is to check if you understand the PCA and KMeans algorithms that we covered in class.
#
# We will walk you through computing the principal components of a matrix that shows the nutrient composition of pizzas of different brands.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

sns.set_theme()

# %% [markdown]
# ## Loading and understanding the data

# %% [markdown]
# ### Exercise 1

# %%
# Your code here:
df = pd.read_csv('Pizza.csv')
print(df.head())
print('//////////////////////////////////////////////')
print(df.info())
print('//////////////////////////////////////////////')
# Out:
#   brand     id   mois   prot    fat   ash  sodium  carb   cal
# 0     A  14069  27.82  21.43  44.87  5.11    1.77  0.77  4.93
# 1     A  14053  28.49  21.26  43.89  5.34    1.79  1.02  4.84
# 2     A  14025  28.35  19.99  45.78  5.08    1.63  0.80  4.95
# 3     A  14016  30.55  20.15  43.13  4.79    1.61  1.38  4.74
# 4     A  14005  30.49  21.28  41.65  4.82    1.64  1.76  4.67
# //////////////////////////////////////////////
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   300 non-null    object
#  1   id      300 non-null    int64
#  2   mois    300 non-null    float64
#  3   prot    300 non-null    float64
#  4   fat     300 non-null    float64
#  5   ash     300 non-null    float64
#  6   sodium  300 non-null    float64
#  7   carb    300 non-null    float64
#  8   cal     300 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 21.2+ KB
# None
# //////////////////////////////////////////////

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Print a numerical summary of each column using the `describe` method.

# %%
# Your code here:
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
print('//////////////////////////////////////////////')
print(df.describe())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14279152072457120533
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6246629376
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8026720086276599388
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 Super with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]
# //////////////////////////////////////////////
#                  id        mois        prot         fat         ash  \
# count    300.000000  300.000000  300.000000  300.000000  300.000000
# mean   20841.040000   40.903067   13.373567   20.229533    2.633233
# std     6962.917222    9.552987    6.434392    8.975658    1.269724
# min    14003.000000   25.000000    6.980000    4.380000    1.170000
# 25%    14093.750000   30.902500    8.060000   14.770000    1.450000
# 50%    24020.500000   43.300000   10.440000   17.135000    2.225000
# 75%    24110.250000   49.115000   20.022500   21.435000    3.592500
# max    34045.000000   57.220000   28.480000   47.200000    5.430000
#
#            sodium        carb         cal
# count  300.000000  300.000000  300.000000
# mean     0.669400   22.864767    3.271000
# std      0.370358   18.029722    0.620034
# min      0.250000    0.510000    2.180000
# 25%      0.450000    3.467500    2.910000
# 50%      0.490000   23.245000    3.215000
# 75%      0.702500   41.337500    3.520000
# max      1.790000   48.640000    5.080000

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Let's inspect the dataset visually.
#
# 1. Get all scatter plots by pairs, and illuminate by the brand. (Hint: `sns.pairplot`. Pass the `corner=True` keyword argument :) )
# 2. Get a correlation matrix for the `pizza` dataframe, and plot it using the `heatmap` function inside `sns`.

# %%
# Your code for 3.1 here:
sns.pairplot(data = df, corner = True, hue = 'brand')

# %%
# Your code for 3.2 here
corr = df.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Getting the principal components

# %% [markdown]
# Now let's use `sklearn` to get the principal components of this data.

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# From `sklearn.decomposition` import `PCA`.

# %%
# Your code here:
from sklearn.decomposition import PCA

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# Prepare your data for PCA:
#
# 1. Define an array `X` with the contents of the `pizza` DataFrame, except for the column `brand`. Print it and compare with the original `pizza` DataFrame (Hint `.values`).
# 2. Scale your data using a standard scaler and print it. Import what you need.

# %%
# Your code for 5.1 here
X = df.drop(['brand', 'id'], axis=1).to_numpy()
y = df['brand'].to_numpy()
print(X)
print(df.values)
# Out:
# [[27.82 21.43 44.87 ...  1.77  0.77  4.93]
#  [28.49 21.26 43.89 ...  1.79  1.02  4.84]
#  [28.35 19.99 45.78 ...  1.63  0.8   4.95]
#  ...
#  [44.55 11.01 16.03 ...  0.64 25.98  2.92]
#  [47.6  10.43 15.18 ...  0.56 24.47  2.76]
#  [46.84  9.91 15.5  ...  0.57 25.48  2.81]]
# [['A' 14069 27.82 ... 1.77 0.77 4.93]
#  ['A' 14053 28.49 ... 1.79 1.02 4.84]
#  ['A' 14025 28.35 ... 1.63 0.8 4.95]
#  ...
#  ['J' 34039 44.55 ... 0.64 25.98 2.92]
#  ['J' 14044 47.6 ... 0.56 24.47 2.76]
#  ['J' 14045 46.84 ... 0.57 25.48 2.81]]

# %%
# Your code for 5.2 here
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
X_std = scaler.transform(X)
print(scaler.scale_)
print(X_std)
# Out:
# [ 9.53705171  6.42365941  8.96068638  1.26760557  0.36973996 17.99964784
#   0.619     ]
# [[-1.37181459  1.25418127  2.74984143 ...  2.97668662 -1.22751105
#    2.68012924]
#  [-1.30156227  1.22771661  2.64047481 ...  3.03077869 -1.21362189
#    2.53473344]
#  [-1.31624186  1.03000998  2.85139615 ...  2.59804213 -1.22584435
#    2.71243942]
#  ...
#  [ 0.3823963  -0.36794707 -0.46866201 ... -0.07951534  0.1730719
#   -0.56704362]
#  [ 0.70220164 -0.45823828 -0.56352082 ... -0.29588362  0.08918137
#   -0.82552504]
#  [ 0.62251244 -0.53918903 -0.52780927 ... -0.26883759  0.14529358
#   -0.7447496 ]]

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Create a PCA instance, call it `pca`. Fit it with the data X.

# %%
# Your code here
pca = PCA()
pca.fit(X_std)
print(pca.components_)
# Out:
# [[ 6.47093729e-02  3.78760904e-01  4.46665915e-01  4.71889526e-01
#    4.35702887e-01 -4.24913712e-01  2.44487304e-01]
#  [-6.28275866e-01 -2.69706650e-01  2.34379085e-01 -1.10990417e-01
#    2.01661652e-01  3.20312078e-01  5.67457559e-01]
#  [-4.21668945e-01  7.46027442e-01 -1.99308714e-01  5.62726863e-02
#   -4.55168874e-01  5.22365058e-02  1.13315588e-01]
#  [-2.20721584e-01 -1.05931982e-02 -5.07042158e-01  5.52398549e-01
#    4.46276890e-01  3.34339481e-01 -2.79263154e-01]
#  [-6.47029345e-03 -3.87982788e-01  1.73367634e-01  6.70885701e-01
#   -6.02614079e-01  7.43689883e-03  7.80031747e-02]
#  [ 4.46449902e-01 -1.71520299e-04 -5.25402868e-01  5.88609281e-02
#    3.13098518e-03 -5.08853524e-04  7.21913853e-01]
#  [ 4.18569035e-01  2.76764643e-01  3.77671525e-01  5.60214003e-02
#   -5.24323817e-04  7.76067911e-01  1.20598098e-02]]

# %% [markdown]
# ### Exercise 7

# %% [markdown]
# What are the explained variances of the principal components? What are the explained variance ratios? Print both of them.

# %%
# Your code here
print(pca.explained_variance_)
print(pca.explained_variance_ratio_)
# Out:
# [4.18573434e+00 2.29811778e+00 4.15948838e-01 9.54925358e-02
#  2.77695834e-02 3.38738483e-04 9.55061572e-06]
# [5.95968842e-01 3.27208198e-01 5.92231918e-02 1.35963182e-02
#  3.95385973e-03 4.82299078e-05 1.35982576e-06]

# %% [markdown]
# Expected answer:
# ```
# [4.18573434e+00 2.29811778e+00 4.15948838e-01 9.54925358e-02
#  2.77695834e-02 3.38738483e-04 9.55061572e-06]
# [5.95968842e-01 3.27208198e-01 5.92231918e-02 1.35963182e-02
#  3.95385973e-03 4.82299078e-05 1.35982576e-06]
# ```

# %% [markdown]
# ### Exercise 8

# %% [markdown]
# Get two line plots using seaborn. Give them appropiate titles and make them pretty. :)
# 1. One with the explained variance per principal component
# 2. One with the **cumulative** explained ratios.

# %%
# Your code for 8.1 here
plot = sns.lineplot(x = np.arange(len(pca.explained_variance_)) + 1, y = pca.explained_variance_)
plot.set_title("Explained variance per component")
plot.set_xlabel("Principal components")
plot.set_ylabel("Explained variance")
# Out:
# Text(0, 0.5, 'Explained variance')

# %%
# Your code for 8.2 here
plot = sns.lineplot(x = np.arange(len(pca.explained_variance_ratio_)) + 1, y = np.cumsum(pca.explained_variance_ratio_))
plot.set_title("Cumulative explained ratios")
plot.set_xlabel("Principal components")
plot.set_ylabel("Running sum of explained ratios")
# Out:
# Text(0, 0.5, 'Running sum of explained ratios')

# %% [markdown]
# ### Exercise 9

# %% [markdown]
# If we want more than 90% explaned variance, how many principal components do we need? What about 95%?

# %% [markdown]
# Your answer here:
#
# For more than 90%, we need at least 2 principal components; for more than 95% we need at least 3.

# %% [markdown]
# ### Exercise 10

# %% [markdown]
# We will wrap up our PCA by showing the projection of all the data to the two principal components.
#
# 1. Create a new PCA object with `n_components=2`, call it `pca_2`, and fit it with `X`. Use the `transform` method to project the data to the plane. Call the output of `transform` an array `z`
# 2. Use `sns.scatterplot` with the first column of `z` as `x`, the second column of `z` as `y`, and `pizza["brand"]` as the `hue`.

# %%
# Your code for 10.1 and 10.2 here
pca_2 = PCA(n_components=2).fit(X)
z = pca_2.transform(X)
plt.figure(figsize=(10,8))
sns.scatterplot(x = z[:,0], y = z[:,1], hue = df['brand'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ## Comparing with KMeans

# %% [markdown]
# ### Exercise 11
#
# Let's assume we didn't know the brands, could we recover them using K-means clustering?
#
# 1. create a `KMeans` instance with `len(pizza["brand"].unique())` clusters, call it `kmeans`.
# 2. Fit it on the `z` that we just plotted in the last exercise.
# 3. Plot a `sns.scatterplot` with `hue` given by the cluster ids. Compare it with the plot from the previous exercise (Hint: `kmeans.labels_`)

# %%
# Your code here. 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = len(df["brand"].unique()))
kmeans.fit(z)
fig, ax = plt.subplots(1, 2, sharex=True, figsize=(24,8))
fig.suptitle('Comparison of actual brand vs KMeans')
sns.scatterplot(ax = ax[0], x = z[:,0], y = z[:,1], hue = df['brand'],legend='full')
ax[0].set_title('Hue by brand')
ax[0].legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
sns.scatterplot(ax = ax[1], x = z[:,0], y = z[:,1], hue = kmeans.labels_, palette='cool_r')
ax[1].set_title('Hue by cluster')
ax[1].legend(labels=np.unique(kmeans.labels_), bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
